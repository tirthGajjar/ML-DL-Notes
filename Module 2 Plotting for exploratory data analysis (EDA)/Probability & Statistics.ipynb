# %%
import numpy as np
from sympy import var, init_printing, latex, exp
import matplotlib.pyplot as plt
from IPython.display import display, Latex

init_printing(use_latex=True)
# %matplotlib inline

# %% [markdown]
# # Gaussian/Normal Distribution
#
# An easily understood application for Calculus lies in statistics, in the forms of the normal or Gaussian distribution.
# The normal distribution or "bell curve" looks like this when plotted in the IPython workbook interface:

# %%
fig = plt.gcf()
fig.set_size_inches(8,5)
f = lambda x: exp(-x**2/2)
x = np.linspace(-4,4,100)
y = np.array([f(v) for v in x],dtype='float')
plt.grid(True)
plt.title('Gaussian Curve')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x,y,color='gray')
plt.fill_between(x,y,0,color='#c0f0c0')
plt.show()

# %% [markdown]
# The plotted function, $$\large f(x) = e^{- \frac{x^{2}}{2}}$$
# describes the distribution of certain naturally occurring events. This function is the focus of much attention in statistics and the natural sciences because of its ability to predict statistical distributions based on sparse data.

# %%
import numpy as np
from sympy import *
from IPython.display import *
init_printing(use_latex=True)
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace(50,150,100)
y = np.array([pdf(v,100,15) for v in x],dtype='float')
plt.grid(True)
plt.title('Probability Density Function')
plt.xlabel('IQ')
plt.ylabel('Y')
plt.text(122,0.023,'$\mu = 100$',fontsize=16)
plt.text(122,0.021,'$\sigma = 15$',fontsize=16)
plt.plot(x,y,color='gray')
plt.fill_between(x,y,0,color='#c0f0c0')
plt.show()

# %% [markdown]
# $$\small  pdf (x,\mu,\sigma) = \frac{1}{ \sigma\sqrt{2 \pi}} e^{\left(-\frac{{\left(\mu - x\right)}^{2}}{2 \, \sigma^{2}}\right)}$$

# %% [markdown]
# If x is a continous variable and x's pdf looks like a bell curve like above, we can say that x follows Gaussian distribution

# %% [markdown]
# Why learn about distributions?
# - distributions are very simple models that can
